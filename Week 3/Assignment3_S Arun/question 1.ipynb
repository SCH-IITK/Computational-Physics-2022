# %%
#question 1
import numpy as np
import matplotlib.pyplot as plt
v=[0,
0.069478,
0.137694,
0.204332,
0.269083,
0.331656,
0.391771,
0.449167,
0.503598,
0.554835,
0.602670,
0.646912,
0.687392,
0.723961,
0.756491,
0.784876,
0.809032,
0.828897,
0.844428,
0.855608,
0.862439,
0.864945,
0.863172,
0.857184,
0.847067,
0.832926,
0.814882,
0.793077,
0.767666,
0.738824,
0.706736,
0.671603,
0.633638,
0.593065,
0.550118,
0.505039,
0.458077,
0.409488,
0.359533,
0.308474,
0.256576,0.204107,
0.151330,
0.098509,
0.045905,
-0.006228,
-0.057640,
-0.108088,
-0.157338,
-0.205163,
-0.251347,
-0.295685,
-0.337984,
-0.378064,
-0.415757,
-0.450909,
-0.483382,
-0.513052,
-0.539809,
-0.563563,
-0.584234,
-0.601764,
-0.616107,
-0.627235,
-0.635136,
-0.639814,
-0.641289,
-0.639596,
-0.634786,
-0.626922,
-0.616085,
-0.602366,
-0.585872,
-0.566720,
-0.545039,
-0.520970,
-0.494661,
-0.466272,
-0.435970,
-0.403929,
-0.370330,
-0.335357,
-0.299201,
-0.262054,
-0.224114,
-0.185575,
-0.146636,
-0.107492,
-0.068339,
-0.029370,
0.009227,
0.047268,
0.084574,
0.120970,
0.156290,
0.190375,
0.223073,
0.254244,
0.283753,
0.311479,
0.337308]
x=np.linspace(0,100,101)
plt.plot(x,v)
plt.show()

# %%
#1
s=[0]*101
for i in range (100):
     s[i+1]=s[i]+1*(v[i]+v[i+1])/2
print('The required distance time function:')
for i in range (100):
     print(str(i)+' '+str(s[i])+'\n')
# Out:
# The required distance time function:
# 0 0
#
# 1 0.034739
#
# 2 0.138325
#
# 3 0.309338
#
# 4 0.5460455
#
# 5 0.8464149999999999
#
# 6 1.2081285
#
# 7 1.6285975
#
# 8 2.10498
#
# 9 2.6341965
#
# 10 3.212949
#
# 11 3.83774
#
# 12 4.504892
#
# 13 5.2105685
#
# 14 5.9507945
#
# 15 6.721477999999999
#
# 16 7.518431999999999
#
# 17 8.337396499999999
#
# 18 9.174058999999998
#
# 19 10.024076999999998
#
# 20 10.883100499999998
#
# 21 11.746792499999998
#
# 22 12.610850999999998
#
# 23 13.471028999999998
#
# 24 14.323154499999998
#
# 25 15.163150999999997
#
# 26 15.987054999999998
#
# 27 16.7910345
#
# 28 17.571406
#
# 29 18.324651
#
# 30 19.047431
#
# 31 19.736600499999998
#
# 32 20.389221
#
# 33 21.0025725
#
# 34 21.574164
#
# 35 22.1017425
#
# 36 22.5833005
#
# 37 23.017083
#
# 38 23.4015935
#
# 39 23.735597000000002
#
# 40 24.018122
#
# 41 24.248463500000003
#
# 42 24.426182000000004
#
# 43 24.551101500000005
#
# 44 24.623308500000004
#
# 45 24.643147000000003
#
# 46 24.611213000000003
# ...

# %%
#2
plt.plot(x,s)
plt.plot(x,v)
plt.show()
