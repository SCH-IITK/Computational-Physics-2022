# %%
#Question 3:

import numpy as np
import matplotlib.pyplot as plt
file_name = 'smt.txt'
img = np.loadtxt(file_name)
plt.imshow(img)
plt.colorbar()
plt.show()

# plt.figure(figsize=(10,10))
# ax = plt.axes(projection="3d")
# Z = img
# x = np.arange(len(Z))
# y = np.arange(len(Z[0]))
# (x,y) = np.meshgrid(x,y)
    
# surface_plot= ax.plot_surface(x, y, Z, cmap='viridis')

# plt.show()
